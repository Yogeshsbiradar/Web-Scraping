# %%
from bs4 import BeautifulSoup
import requests
res = requests.get('https://techcrunch.com/')
soup = BeautifulSoup(res.text,'lxml')
for heading in soup.find_all(["div","src"]):
    print(heading.name + ' ' + heading.text.strip())
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://techcrunch.com/')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile('.jpg')})
for image in images: 
    print(image['src']+'\n')
# Out:
# div The Latest
#
#
#
#
#
# 				Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
#
#
#
#
#
#
#
#
#
#
# Load More
# div The Latest
#
#
#
#
#
# 				Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
#
#
#
#
#
#
#
#
#
#
# Load More
# div The Latest
#
#
#
#
#
# 				Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
#
#
#
#
#
#
#
#
#
#
# Load More
# div The Latest
#
#
#
#
#
# 				Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
#
#
#
#
#
#
#
#
#
#
# Load More
# div Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
#
#
#
#
#
#
#
#
#
#
# Load More
# div Cendana Capital, which has been backing seed funds for a decade, has $278 million more to invest
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Connie Loizos
#
#
#
#
#
# 		When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
# div Jun 30, 2020
#
#
# 				Connie Loizos
# div Jun 30, 2020
#
#
# 				Connie Loizos
# div When in 2010, former VC Michael Kim set out to raise a fund that he would invest in a spate of micro VC managers, the investors to which he turned didn’t get it. Why pay Kim and his firm, Cendan
# div Facebook shuts down Hobbi, its experimental app for documenting personal projects
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sarah Perez
#
#
#
#
#
# 		Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
# div Jun 30, 2020
#
#
# 				Sarah Perez
# div Jun 30, 2020
#
#
# 				Sarah Perez
# div Facebook’s recently launched app, Hobbi, an experiment in short-form content creation around personal projects, hobbies, and other Pinterest-y content, is already shutting down. The app first ar
# div Lyft’s self-driving test vehicles are back on public roads in California
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Kirsten Korosec
#
#
#
#
#
# 		Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
# div Jun 30, 2020
#
#
# 				Kirsten Korosec
# div Jun 30, 2020
#
#
# 				Kirsten Korosec
# div Lyft’s self-driving vehicle division has restarted testing on public roads in California, several months after pausing operations amid the COVID-19 pandemic. Lyft’s Level 5 program said Tuesda
# div TransferWise to offer investment products but has ‘no plans’ to become a bank
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Steve O'Hear
#
#
#
#
#
# 		TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
# div Jun 30, 2020
#
#
# 				Steve O'Hear
# div Jun 30, 2020
#
#
# 				Steve O'Hear
# div TransferWise, the London-headquartered international money transfer service recently valued at $3.5 billion, has secured an additional license with U.K. regulators to enable it to offer investment pro
# div Elementary Robotics is making its quality assurance robots commercially available
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
# div Jun 30, 2020
#
#
# 				Jonathan Shieber
# div Jun 30, 2020
#
#
# 				Jonathan Shieber
# div Two years and more than $17 million after it first began working on its robots for quality assurance, the Los Angeles-based Elementary Robotics has finally made its products commercially available. Th
# div NASA pays out $51 million to small businesses with big ideas
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
# div Jun 30, 2020
#
#
# 				Devin Coldewey
# div Jun 30, 2020
#
#
# 				Devin Coldewey
# div NASA has announced its latest batch of small business grants, providing more than 300 businesses a total of $51 million in crucial early-stage funding. These “phase I” projects receive up
# div Skygauge’s innovative tilting rotor drones are up for pre-order, with deliveries in 2021
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
# div Jun 30, 2020
#
#
# 				Brian Heater
# div Jun 30, 2020
#
#
# 				Brian Heater
# div I have had a few occasions to see Skygauge’s drones in-person, primarily on visits to Asia. The Canadian team is involved in HAX’s program and has spent time working out of their Shenzhen offices.
# div Dfinity demonstrates its TikTok clone, opens up its ‘Internet Computer’ to outside developers
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Mike Butcher
#
#
#
#
#
# 		Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
# div Jun 30, 2020
#
#
# 				Mike Butcher
# div Jun 30, 2020
#
#
# 				Mike Butcher
# div Dfinity appeared in 2018, amid the flurry of investments in the blockchain space. It raised $102 million in funding at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychai
# div Facebook bans ‘violent network’ of far-right boogaloo accounts
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
# div Jun 30, 2020
#
#
# 				Taylor Hatmaker
# div Jun 30, 2020
#
#
# 				Taylor Hatmaker
# div Facebook took action to remove a network of accounts Tuesday related to the “boogaloo” movement, a firearm-obsessed anti-government ideology that focuses on preparing for and potentially i
# div What 👁👄👁.fm means for Silicon Valley
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ravi Mehta
#
#
#
#
#
# 		VCs should take note. These are the people who will build the next Facebook.
# div Jun 30, 2020
#
#
# 				Ravi Mehta
# div Jun 30, 2020
#
#
# 				Ravi Mehta
# div VCs should take note. These are the people who will build the next Facebook.
# div Apple device management company Jamf files S-1 as it prepares to go public
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
#
#
#
#
#
# 		Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
# div Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
# div Jun 30, 2020
#
#
# 				Ron Miller
#
# 				Alex Wilhelm
# div Jamf, the Apple device management company, filed to go public today. Jamf might not be a household name, but the Minnesota company has been around since 2002 helping companies manage their Apple equip
# div SpaceX successfully launches GPS III space vehicle on behalf of the US Space Force
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
# div Jun 30, 2020
#
#
# 				Darrell Etherington
# div Jun 30, 2020
#
#
# 				Darrell Etherington
# div SpaceX successfully launched a GPS III satellite for the U.S. Space Force today. The Space Force took over the U.S. in-space GPS assets from the Air Force when it became its own dedicated wing of the
# div Samsung will not exhibit at IFA 2020, opts for digital event instead
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Brian Heater
#
#
#
#
#
# 		Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
# div Jun 30, 2020
#
#
# 				Brian Heater
# div Jun 30, 2020
#
#
# 				Brian Heater
# div Stop me if you’ve heard this one before. A major company just announced that it will not be taking part in an in-person trade show, instead opting to go online only. After early reports from South K
# div Oculus co-founder and games industry vets form Mountaintop Studios
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Devin Coldewey
#
#
#
#
#
# 		Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
# div Jun 30, 2020
#
#
# 				Devin Coldewey
# div Jun 30, 2020
#
#
# 				Devin Coldewey
# div Oculus co-founder Nate Mitchell is heading up a new game development house called Mountaintop Studios, joined by colleagues from around the gaming industry. The company aims to leave the crunch and to
# div Dear Sophie: Is immigration happening? Who can I hire?
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Sophie Alcorn
#
#
#
#
#
# 		Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
# div Jun 30, 2020
#
#
# 				Sophie Alcorn
# div Jun 30, 2020
#
#
# 				Sophie Alcorn
# div Sophie Alcorn Contributor Share on Twitter Sophie Alcorn is the founder of Alcorn Immigration Law in Silicon Valley and 2019 Global Law Experts Awards’ “Law Firm of the Year in California for Entr
# div To promote diversity, rewire your broken corporate culture
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Travis Montaque
#
#
#
#
#
# 		Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
# div Jun 30, 2020
#
#
# 				Travis Montaque
# div Jun 30, 2020
#
#
# 				Travis Montaque
# div Once we learn to celebrate everyone for who they truly are, we can begin to make systemic changes to our company cultures. We must take our next steps together.
# div With advertiser boycott growing, lawmakers press Facebook on white supremacy
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Taylor Hatmaker
#
#
#
#
#
# 		In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
# div Jun 30, 2020
#
#
# 				Taylor Hatmaker
# div Jun 30, 2020
#
#
# 				Taylor Hatmaker
# div In a new letter to Mark Zuckerberg, three Democratic lawmakers pressed the Facebook chief executive for accountability on his company’s role in amplifying white supremacy and allowing violent ex
# div Health class is outdated, so Lessonbee wants to fix it
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Natasha Mascarenhas
#
#
#
#
#
# 		Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
# div Jun 30, 2020
#
#
# 				Natasha Mascarenhas
# div Jun 30, 2020
#
#
# 				Natasha Mascarenhas
# div Sex education in the United States is complicated. One example: For decades, the United States invested billions into abstinence-only programs. Eventually, schools rejected government funding for thes
# div NASA sets path for up to six more Artemis moon exploration missions with SLS booster order
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Darrell Etherington
#
#
#
#
#
# 		NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
# div Jun 30, 2020
#
#
# 				Darrell Etherington
# div Jun 30, 2020
#
#
# 				Darrell Etherington
# div NASA has laid the groundwork for an order of up to six additional SLS solid core booster rockets, from supplier Northrop Grumman, the agency announced this week. The six additional boosters would join
# div Discord now has a $3.5B valuation and $100M for a sales pitch lighter on the gaming
#
#
#
#
# 		Jun 30, 2020
#
#
# 				Jonathan Shieber
#
#
#
#
#
# 		Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
# div Jun 30, 2020
#
#
# 				Jonathan Shieber
# div Jun 30, 2020
#
#
# 				Jonathan Shieber
# div Discord wants to be more than just a place for gamers and is now billing itself as the Slack for users’ social lives. The new pitch, and a new funding round of $100 million at a reported valuat
# https://techcrunch.com/wp-content/uploads/2020/06/Michael-Kim.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2019/07/lyft-level-5-self-driving.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/Kristo-Kaarmann.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2019/02/GettyImages-1018210700.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2019/10/GettyImages-549605335.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/Tank-Landed.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/cancan-app.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/boogaloo-GettyImages-1216297285.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1189378660.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1134973782.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2017/09/gettyimages-841564132.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/SA-at-TC.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1181807409.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2019/10/GettyImages-1177753363.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/ksc-20200616-ph-jbs01_0019-2.jpg?w=300&h=160&crop=1
#
# https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1215460368.jpg?w=300&h=160&crop=1
